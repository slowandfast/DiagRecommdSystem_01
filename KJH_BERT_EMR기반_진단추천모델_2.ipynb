# %% [markdown]
# <a href="https://colab.research.google.com/github/slowandfast/DiagRecommdSystem_01/blob/main/KJH_BERT_EMR%EA%B8%B0%EB%B0%98_%EC%A7%84%EB%8B%A8%EC%B6%94%EC%B2%9C%EB%AA%A8%EB%8D%B8_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch
# !pip install transformers
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
file_path = '/content/신장내과_본원_외래_20230701_20231231_filtered.xlsx'
df = pd.read_excel(file_path)
df.head(5)
# Out:
#   ICD10         진단코드                            한글진단명        영문진단명  나이 성별  \
# 0  N391  N391.000.01           Persistent proteinuria     지속성 단백뇨증  51  F
# 1  N184  N184.001.00  Chronic kidney disease, stage 4  만성 신장질환(4기)  79  M
# 2  N184  N184.001.00  Chronic kidney disease, stage 4  만성 신장질환(4기)  71  F
# 3  N185  N185.011.00  Chronic kidney disease, stage 5  만성 신장질환(5기)  52  F
# 4  N183  N183.001.00  Chronic kidney disease, stage 3  만성 신장질환(3기)  82  F
#
#       기록작성일   작성과 작성의사                           주호소  \
# 0  20230703  신장내과  NPN                           NaN
# 1  20230703  신장내과  NPP  CKD4, Cr 2.26, eGFR 29ml/min
# 2  20230703  신장내과  NPP                          CKD4
# 3  20230703  신장내과  NPP           Cr 3.74, eGFR 13.56
# 4  20230703  신장내과  NPK               lab abnormality
#
#                                                  현병력  \
# 0  115-61-61_x000D_\n2023.5.10._x000D_\n_x000D_\n...
# 1  130/61/69_x000D_\n요증상(-), edema(-), 요독증상(-), D...
# 2  153/75/85_x000D_\n요증상(-), edema(-), 요독증상(-), D...
# 3  148/90/64_x000D_\n요증상(-), edema mild_x000D_\nC...
# 4  선생님 안녕하십니까_x000D_\n_x000D_\n상기 병명으로 입원하여 치료중인 ...
#
#                                                 현병력2  \
# 0  115-61-61  2023.5.10.    검진상 단백뇨 의심 소견 +  거품뇨 ...
# 1  130/61/69  요증상(-), edema(-), 요독증상(-), DOE(-)  ...
# 2  153/75/85  요증상(-), edema(-), 요독증상(-), DOE(-)  ...
# 3  148/90/64  요증상(-), edema mild  CKD d/t ADPKD로 ...
# 4  선생님 안녕하십니까    상기 병명으로 입원하여 치료중인 환자입니다.    환자 입...
#
#                                             transstr  \
# 0  115-61-61 2023.5.10.Suspicion of proteinuria i...
# 1  130/61/69 Symptoms (-), edema (-), urbanic sym...
# 2  153/75/85 osophy (-), edema (-), urinary sympt...
# 3  148/90/64 Idema Mild CKD D/T ADPKD has been tr...
# 4  Hello teacher, I am a patient who is being hos...
#
#                                                  과거력
# 0  자궁적출_x000D_\n_x000D_\n당뇨 고혈압 없음_x000D_\n_x000D...
# 1  DM/HTN (-/+)_x000D_\nHerb med hx (-): 영양제 복용중임...
# 2  DM/HTN (+/+)_x000D_\nHerb med hx (-)_x000D_\nA...
# 3  DM/HTN (-/+)_x000D_\nHerb med hx (-)_x000D_\nA...
# 4  # Cerebral infarction, Lt MCA territory (F cor...

# %%
# 전처리 1
df['주호소2'] = df['주호소'].str.replace("_x000D_", " ")
df['주호소2'] = df['주호소2'].str.replace("\n", " ")
df['주호소2'] = df['주호소2'].str.strip()

df['현병력2'] = df['현병력'].str.replace("_x000D_", " ")
df['현병력2'] = df['현병력2'].str.replace("\n", " ")
df['현병력2'] = df['현병력2'].str.strip()

df['과거력2'] = df['과거력'].str.replace("_x000D_", " ")
df['과거력2'] = df['과거력2'].str.replace("\n", " ")
df['과거력2'] = df['과거력2'].str.strip()

# %%
df.head(100)
# Out:
#    ICD10         진단코드                                   한글진단명         영문진단명  \
# 0   N391  N391.000.01                  Persistent proteinuria      지속성 단백뇨증
# 1   N184  N184.001.00         Chronic kidney disease, stage 4   만성 신장질환(4기)
# 2   N184  N184.001.00         Chronic kidney disease, stage 4   만성 신장질환(4기)
# 3   N185  N185.011.00         Chronic kidney disease, stage 5   만성 신장질환(5기)
# 4   N183  N183.001.00         Chronic kidney disease, stage 3   만성 신장질환(3기)
# ..   ...          ...                                     ...           ...
# 95  N178  N178.011.00  Acute kidney injury(AKI), Nontraumatic  급성 신손상(비외상성)
# 96  N178  N178.011.00  Acute kidney injury(AKI), Nontraumatic  급성 신손상(비외상성)
# 97  N183  N183.001.00         Chronic kidney disease, stage 3   만성 신장질환(3기)
# 98  N185  N185.007.00    End stage kidney disease on dialysis    말기 신장병 투석중
# 99  N059  N059.002.07                                      GN         사구체신염
#
#     나이 성별     기록작성일   작성과 작성의사                             주호소  \
# 0   51  F  20230703  신장내과  NPN                             NaN
# 1   79  M  20230703  신장내과  NPP    CKD4, Cr 2.26, eGFR 29ml/min
# 2   71  F  20230703  신장내과  NPP                            CKD4
# 3   52  F  20230703  신장내과  NPP             Cr 3.74, eGFR 13.56
# 4   82  F  20230703  신장내과  NPK                 lab abnormality
# ..  .. ..       ...   ...  ...                             ...
# 95  62  M  20230719  신장내과  NPH                       azotemia
# 96  80  M  20230719  신장내과  NPH     consultation for operation
# 97  71  M  20230719  신장내과  NPH  consultation for contrast use
# 98  37  M  20230719  신장내과  NPH                       KONOS 등록
# 99  41  F  20230719  신장내과  NPC                             단백뇨
#
#                                                   현병력  \
# 0   115-61-61_x000D_\n2023.5.10._x000D_\n_x000D_\n...
# 1   130/61/69_x000D_\n요증상(-), edema(-), 요독증상(-), D...
# 2   153/75/85_x000D_\n요증상(-), edema(-), 요독증상(-), D...
# 3   148/90/64_x000D_\n요증상(-), edema mild_x000D_\nC...
# 4   선생님 안녕하십니까_x000D_\n_x000D_\n상기 병명으로 입원하여 치료중인 ...
# ..                                                ...
# 95      안녕하십니까 교수님._x000D_\n_x000D_\n# CM on lt. o...
# 96      상기 환자는 진단명[Hyperplasia of prostate with ob...
# 97      상기 환자는 진단명[Aneurysm, P-comm](으)로 현재 치료중인 7...
# 98  _x000D_\nkonos f/u_x000D_\nHD 주3회 월,수,금 at 영천요...
# 99  2011. U/A P 2+_x000D_\n2021. U/A P 2+ RBC 0-2_...
#
#                                                  현병력2  \
# 0   115-61-61  2023.5.10.    검진상 단백뇨 의심 소견 +  거품뇨 ...
# 1   130/61/69  요증상(-), edema(-), 요독증상(-), DOE(-)  ...
# 2   153/75/85  요증상(-), edema(-), 요독증상(-), DOE(-)  ...
# 3   148/90/64  요증상(-), edema mild  CKD d/t ADPKD로 ...
# 4   선생님 안녕하십니까    상기 병명으로 입원하여 치료중인 환자입니다.    환자 입...
# ..                                                ...
# 95  안녕하십니까 교수님.    # CM on lt. occipital lobe with...
# 96  상기 환자는 진단명[Hyperplasia of prostate with obstru...
# 97  상기 환자는 진단명[Aneurysm, P-comm](으)로 현재 치료중인 70세(M...
# 98  konos f/u  HD 주3회 월,수,금 at 영천요양병원     Dwt 92.8...
# 99  2011. U/A P 2+  2021. U/A P 2+ RBC 0-2  2023. ...
#
#                                              transstr  \
# 0   115-61-61 2023.5.10.Suspicion of proteinuria i...
# 1   130/61/69 Symptoms (-), edema (-), urbanic sym...
# 2   153/75/85 osophy (-), edema (-), urinary sympt...
# 3   148/90/64 Idema Mild CKD D/T ADPKD has been tr...
# 4   Hello teacher, I am a patient who is being hos...
# ..                                                ...
# 95  Hello, Professor.# Cm on lt.OCCIPITAL LOBE wit...
# 96  The patient is a 79 -year -old (m) patient cur...
# 97  The patient is a 70-year-old patient currently...
# 98  Konos F/U HD 3 times a week, Wed, Gold AT Yeon...
# 99  2011. U/A P 2+  2021. U/A P 2+ RBC 0-2  2023. ...
#
#                                                   과거력  \
# 0   자궁적출_x000D_\n_x000D_\n당뇨 고혈압 없음_x000D_\n_x000D...
# 1   DM/HTN (-/+)_x000D_\nHerb med hx (-): 영양제 복용중임...
# 2   DM/HTN (+/+)_x000D_\nHerb med hx (-)_x000D_\nA...
# 3   DM/HTN (-/+)_x000D_\nHerb med hx (-)_x000D_\nA...
# 4   # Cerebral infarction, Lt MCA territory (F cor...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                       HTN/DM (-/-)
#
#                              주호소2  \
# 0                             NaN
# 1    CKD4, Cr 2.26, eGFR 29ml/min
# 2                            CKD4
# 3             Cr 3.74, eGFR 13.56
# 4                 lab abnormality
# ..                            ...
# 95                       azotemia
# 96     consultation for operation
# 97  consultation for contrast use
# 98                       KONOS 등록
# 99                            단백뇨
#
#                                                  과거력2
# 0                  자궁적출    당뇨 고혈압 없음    no medication
# 1   DM/HTN (-/+)  Herb med hx (-): 영양제 복용중임.  Alco...
# 2   DM/HTN (+/+)  Herb med hx (-)  Alcohol/smoking...
# 3   DM/HTN (-/+)  Herb med hx (-)  Alcohol/smoking...
# 4   # Cerebral infarction, Lt MCA territory (F cor...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                       HTN/DM (-/-)
#
# [100 rows x 16 columns]

# %%
# file_path = '/content/신장내과_본원_외래_20230701_20231231_filtered.xlsx'

# selected_columns = ['ICD10', 'transstr']
# df = pd.read_excel(file_path, usecols=selected_columns)

# print('전체 데이터 수 :',len(df))
# df.head(5)
# Out:
# 전체 데이터 수 : 826
#   ICD10                                           transstr
# 0  N391  115-61-61 2023.5.10.Suspicion of proteinuria i...
# 1  N184  130/61/69 Symptoms (-), edema (-), urbanic sym...
# 2  N184  153/75/85 osophy (-), edema (-), urinary sympt...
# 3  N185  148/90/64 Idema Mild CKD D/T ADPKD has been tr...
# 4  N183  Hello teacher, I am a patient who is being hos...

# %%
# pip install googletrans==4.0.0-rc1
# !pip install googletrans==3.1.0a0
# Out:
# Requirement already satisfied: googletrans==3.1.0a0 in /usr/local/lib/python3.10/dist-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.2.2)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.5.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)

# %%
# 번역
import googletrans

def trans_hng_to_eng(text):
    rtn = ''
    # print('text : ', text )
    try:
        if text is not None:
            translator = googletrans.Translator()
            text = translator.translate(text, dest='en')
            # print('T : ', text.text)
            if text.text is not None:
                rtn = text.text
    except:
        print('text : ', text )
    return rtn

# %%
# df['CC_translated'] = df['주호소2'].apply(trans_hng_to_eng)
# df['PI_translated'] = df['현병력2'].apply(trans_hng_to_eng)
df['PH_translated'] = df['과거력2'].apply(trans_hng_to_eng)
# Out:
# text :  HTN  DM
# text :  # Rt renal pelvis tumor  # Claculus of ureter
# text :  # HTN  # GB cancer (s/p radical cholecystectomy. 2001)
# text :  HTN/DM/Tbc -/-/-
# text :
# text :  DM/HTN/Tbc (-/+/-)
# text :  DM/HTN/Tbc (-/-/-)  Mg, 크릴오일, 관절보호제 등 복용하고 있음    여동생 ESKD 로 KT 시행중
# text :  nan
# text :  nan
# text :  nan
# text :  HTN/DM (+/+)
# text :  DM/HTN (-/-)  Herb med hx (-): 효소 2-3년 복용  Alcohol/smoking (-/-)
# text :  DM/HTN (-/-)  Herb med hx (-)  Alcohol/smoking (-/-)  PCKD로 이식한 조현범님 누나
# text :  DM/HTN (-/-)  Herb med hx (-): 식욕억제제, 다이어트제제, 가르시니아 식물추출물, 한약다이어트  Alcohol/smoking (social/-)
# text :  nan
# text :  nan
# text :  HTN/DM/Tbc -/-/-
# text :  HTN/DM/Tbc +/+/-/
# text :  HTN 3년  DM 20년    smoker: 50년전부터
# text :  no medication  Colon polyp
# text :  DM/HTN/Tbc (-/+/-/-)
# text :  신장질환 가족력 있음 (+)  - 아버지 30 대에 혈액투석 시행하다 38세에 사망함
# text :  아버지 - 신장이식 후 사망  2 Mo ago, uterine myoma (Pain with Bleeding)  2 babies ( 11, 12 세)
# text :  HTN/DM (+/+)
# text :  HTN/DM (-/-)  alcohol/smoking (-/-)
# text :  HTN/DM (-/-)  정신과적 병력 (-)  DL +
# text :  HTN/DM/Tbc -/-/-
# text :  HTN/DM/Tbc +/+/-
# text :  DM/HTN/Tbc (-/+/-)    순환기 내원 이후 약제 복용 중  이전에 검사 받은 적 없었음
# text :  DM/HTN/Tbc (+/+/-)
# text :  DM/HTN/Tbc (-/-/-)    5년전 복강경 수술 - liver resection 시행했다고 함
# text :  nan
# text :  DM/HTN (+/+)  Herb med hx (-): 비타민 B,C 복용중임. 오메가3  Alcohol/smoking(-/1개피/day)
# text :  DM/HTN (-/+)  Herb med hx (-): 양파엑기스  Alcohol/smoking (-/-)
# text :  DM/HTN (-/-)  Herb med hx (-)  Alcohol/smoking (-/-)
# text :  nan
# text :  nan
# text :  HTN/DM (-/-)
# text :  HTN/DM/Tbc -/-/-
# text :  HTN/DM/Tbc +/-/-
# text :  - 주 Prostate cancer  - 부 Kidney, stone, calyceal    HTN +
# text :  DM/HTN/Tbc (-/+/-)
# text :  HTN/DM (+/-)
# text :  HTN/DM (-/-)
# text :  nan
# text :  DM/HTN/Tbc (-/-/-)
# text :  # Lt Nephrectomy hx(1982년 TA)  # SPN(solitary pulmonary nodule)
# text :  # CKD stage 3 d/t r/o DMN  # T2DM /c retinopathy (>30y)
# text :  # DM (40y)  # ILD, UIP  # OA  # s/p cerebellar infarction, both PICA territory  # s/p both IC VA to BA stenosis, right IC ICA stenosis  # s/p unruptured aneurysm on right MCA  # probable idiopathic normal pressure hydrocephalus
# text :  nan
# text :  # Hypertension r/o essential (보건소)  # Type 2 DM (보건소)    # r/o IDA  # r/o ACD    # Cerebral infarction, both MCA multiple dot (iv-tPA) 2015.2  # Cerebral infarction, Left F-cortex (old asymptomatic)  # Ex-smoker
# text :  Adalat Oros 30mg 1 tab ⅹ 1       Adalat Oros 30mg 1 tab ⅹ 2      Renvela 800mg 2 tab ⅹ 2     Cozaar 50mg 1 tab ⅹ 1    Nephvita 1 tab ⅹ 1       Lanston 15mg 1 cap ⅹ 1    Feroba-You  1 tab ⅹ 1       Feburic 40mg 1 tab ⅹ 1      Traspen 37.5mg/325mg 1 tab ⅹ 3
# text :  # CKD d/t CGN  # ESRD on HD   - 2021.11 HD start    # HTN  # Dyslipidemia  # r/o Angina
# text :  [LMC med]  ★clipodogrel  synthyroid 0.05  티페티딘10ng - H2 blocker  자이렌정 0.25 - 수면제  알레린정 - 항히스타민  글리티아연질캡슐  리보트릴정  가베스판연질캡슐 - GI motility  세르비아캡슐 - 정장제  디프로펜정300mg - NSAIDs
# text :  HTN/DM (+/+)
# text :  HTN/DM/Tbc +/-/-
# text :  HTN/DM/Tbc -/-/-
# text :  HTN/DM/Tbc +/-/-
# text :  HTN/DM/Tbc +/-/-
# text :  DM/HTN/Tbc (+/+/-)
# text :  DM/HTN/Tbc (-/+/-)
# text :  DM/HTN/Tbc (-/-/-)    프로페시아 약제 복용 중  요로결석 - 20 대 초 쇄석술로 치료한 적 있음
# text :  nan
# text :  nan
# text :  nan
# text :  HTN/DM (-/-)  Former smoker 1994년 중단, 1 pack/day * 20y
# text :  HTN/DM (+/+)
# text :  DM/HTN (+/+)  Herb med hx (-)  Alcohol/smoking (-/2px20yrs)
# text :  nan
# text :  nan
# text :  nan
# text :  nan
# text :  nan
# text :  nan
# text :  nan
# text :  HTN/DM (+/+)
# text :  HTN/DM/Tbc -/-/-
# text :  HTN/DM/Tbc +/-/-/
# text :  HTN/DM/Tbc +/+/-
# text :  HTN/DM/Tbc +/+/-/
# text :  # BI on L MCA territory (2020.06.09): L MCAO -> complete reperfusion  # BI on L MCA F/BG (2020.04)  # cerebral infarction, left PCA territory (2012.12)  # cerebral infarction, left MCA territory w/ PH1 (2012.12)    # atrial fibrillation => LAA occluder 고려중** -> residual LA thrombi로 보류중~  # HTN r/o essential  # T2DM w/ PPN  # dyslipidemia  # r/o PAOD (ABI 0.9)  # x-smoker (2012.12)
# text :  # BI on L MCA territory (2020.06.09): L MCAO -> complete reperfusion  # BI on L MCA F/BG (2020.04)  # cerebral infarction, left PCA territory (2012.12)  # cerebral infarction, left MCA territory w/ PH1 (2012.12)    # atrial fibrillation => LAA occluder 고려중** -> residual LA thrombi로 보류중~  # HTN r/o essential  # T2DM w/ PPN  # dyslipidemia  # r/o PAOD (ABI 0.9)  # x-smoker (2012.12)
# text :  HTN (2023 9월 진단)  DM(-)
# text :  10년전 CABG   HTN 10년 이상  DM(-)
# text :  nan
# text :  DM/HTN/Tbc (-/-/-)
# text :  HTN/DM (+/-)
# text :  HTN/DM (+/-)
# text :  nan
# text :  홍삼
# text :  nan
# text :  nan
# text :  nan
# text :  건강식품 ?    흑염소 3달간 복용    정형외과 Knee Joint Medication - NSAIDs 인 듯
# text :  nan
# text :  DM/HTN/Tbc (+/+/-)
# text :  nan
# text :  nan
# text :  nan
# text :  nan
# text :  HTN/DM/Tbc +/-/-
# text :  HTN/DM/Tbc +/-/-
# text :  HTN/DM/Tbc -/-/-
# text :  체중 60 --> 51Kg /10 년    오메가 3     염소 엑기스 +
# text :  DM/HTN (+/+)  Herb med hx (-):   Alcohol/smoking (-/-)
# text :  # CKD stage 3  - 2015년 eGFR 60    # Severe MR  # Mod AR/TR   - 220415 TTE : EF 44 LVV 188/105 LVD 7.06/5.67 LVW 1.01/0.94 LA 5.52 LAVI 97 GIII, GH    # HTN    # HCC
# text :  # Sudden deafness, Lt  - ENT에서 dexam 복용중.
# text :  HTN/DM (+/-)
# text :  DM/HTN (-/-)  Herb med hx (-): 단백보충제, 비타민D, 오메가3  Alcohol/smoking (social/2-3개 per day)
# text :  DM/HTN/Tbc (-/-/-)
# text :  DM/HTN/Tbc (+/+/-)    LMC 처방전 (URO)  - scan
# text :  HTN/DM (+/-)
# text :  DM/HTN (-/+)  Herb med hx (-): 홍삼, 오메가3, 콜라겐, 영양제  Alcohol/smoking (-/-)
# text :  DM/HTN (+/+)  Herb med hx (-)  Alcohol/smoking (social/ex-smoker)
# text :  DM/HTN (-/+)  Herb med hx (-)  Alcohol/smoking (-/-, 20px20yrs)
# text :  DM/HTN (-/-)  Herb med hx (-)  Alcohol/smoking (Social/1px30yrs)
# text :  nan
# text :  nan
# text :  HTN/DM (+, 현재 미복용 상태/-)
# text :  HTN/DM (+/+)
# text :  HTN/DM (-/-)
# text :  HTN/DM/Tbc +/+/-
# text :  HTN/DM/Tbc +/+/-
# text :  # NHL, AITL, stage IV (BM) : 2019-9-23    # AutoSCT (BuCyE): 2020-6-1     # Allo-SCT : 2021.7.22      # GU : 2021.12.1  # HBV carrier    - on Viread
# text :  HTN(-), DM (-)
# text :  nan
# text :  FHx - negative  NP - 언어장애 +
# text :  어머니 - ESKD - DMN    3형제 다른 분 특이 소견 없음  No hearing impairment    결혼 + 애기는 없음.
# text :  DM/HTN/Tbc (-/-/-)
# text :  HTN/DM -/-
# text :  HTN/DM -/-
# text :  HTN/DM/Tbc +/-/-
# text :  HTN/DM/Tbc -/-/-
# text :  HTN/DM/Tbc -/-/-
# text :  HTN/DM/Tbc -/-/-
# text :  Mg 제재 복용    2023.8. Cbr aneurym - 동산병원, 아산병원 - inoperable ??
# text :  # RA
# text :  HTN/DM (-/-)  alcohol/smoking (+/+)
# text :  HTN/DM (-/-)  alcohol/smoking (+/+)
# text :  HTN/DM (+/-)
# text :  HTN/DM (+/+)
# text :  HTN/DM/Tbc -/-/-
# text :  DM/HTN (+/+)  Herb med hx (-): 한약, 유산균, 오메가3  Alcohol/smoking (-/ex-smoker)
# text :  DM/HTN/Tbc (+/+/-)    current med  - 미카테르정, 자디앙정, 리바로정  으로 약제 변경
# text :  nan
# text :  # HTN  # BPH
# text :  HTN/DM (-/+)
# text :  DM/HTN (-/-)  Herb med hx (-): 루테인, 칼슘, 마그네슘  Alcohol/smoking (-/-)
# text :  nan
# text :  nan
# text :  HTN/DM/Tbc +/+/-
# text :  HTN/DM/Tbc +/+/-
# text :  HTN/DM/Tbc +/-/-
# text :  nan
# text :  HTN(-), DM(-)    smoking(-)
# text :  nan
# text :  nan
# text :  nan
# text :  DM/HTN/Tbc (-/-/-)    가족력 : 언니 가 현미경적 혈뇨가 간헐적으로 있다고 들었음
# text :  HTN/DM/Tbc +/+/-
# text :  nan
# text :  nan
# text :  공대 대학원 Toluene exposure 병력 +    Vit C & Multivitamin
# text :  DM/HTN/Tbc (-/+/-)
# text :  # CKD stage 3 d/t r/o DM    # DM (10y)  # Dyslipidemia  # severe OA
# text :  HTN/DM/Tbc +/-/-/-
# text :  HTN/DM/Tbc +/+/-
# text :  HTN/DM/Tbc +/-/-
# text :  HTN/DM/Tbc -/-/-
# text :  HTN/DM/Tbc +/-/-/
# text :  # ESRD on HD
# text :  HTN/DM (+/-)
# text :  HTN/DM (+/+)
# text :  DM/HTN (-/-)  Herb med hx (-): 2022년 고3때 한약 2재 복용함.  Alcohol/smoking (-/-)
# text :  nan
# text :  nan
# text :  nan
# text :  HTN/DM (+/+)
# text :  HTN/DM/Tbc -/-/-
# text :  HTN/DM/Tbc -/-/-
# text :  HTN    * 작은 아버지가 투석 중.
# text :  # Aneurysmal rupture, isthmus r/o mycotic  # s/p carotid artery stent???(LMC-파티마병원, 2018.10.30)  # HTN  # DM  # dyslipidemia  # AF  # mod MVR
# text :  nan
# text :  nan
# text :  nan
# text :  DM/HTN/Tbc (-/+/-)  current med
# text :  HTN/DM (-/-)  신장질환 가족력 (-)
# text :  HTN/DM (+/+)
# text :  HTN/DM/Tbc -/-/-/
# text :  nan
# text :  DM & Hypertension free
# text :  우측 무릎 통증으로 치료 중
# text :  # CKD  # HTN  # pAF r/o HF  # cerebral infarction,Lt, precentral gyrus(2022.4)  # cerebral infartion, multi-territorial(Rt,PCA,Lt.MCA with HT)(2020.4)  # both bulb plaques
# text :  # HTN (23.12.24)  amlodipine/varsartan 10/160mg  Diazepam 2mg    # renal stone 2회 (곽병원에서 수술한 이력 있음.)
# text :  HTN/DM/Tbc -/-/-
# text :  DM/HTN/Tbc (-/-/-)    2014 년 둘째 분만 당시 이상 없었음    어머니 (오복선님) 본원 신장내과 추적 중 - MN CR state
# text :  nan
# text :  DM/HTN (-/+)  Herb med hx (-)
# text :  nan
# text :  nan
# text :  nan
# text :  HTN/DM (+/-)  형제: 6남매  자녀: 1남3녀
# text :  HTN/DM/Tbc -/-//-
# text :  HTN/DM/Tbc +/+/-
# text :  nan
# text :  DM/HTN/Tbc (-/+/-)  current smoker (+)
# text :  current med  에스메졸정  리비알정 - 2년전부터 복용 중  미가드정 2.5 (편두통으로 가끔 드심)
# text :  DM/HTN/Tbc (-/+/-)    current med  크로바틴정 10  로피롤 에이정  fenofibrate 110  셀메텍플러스정 (20/12.5)
# text :  HTN/DM (+/+)
# text :  nan
# text :  Smoking 1 P/Day    보건소 medication
# text :  nan
# text :  FHX - no kidney Ds  Statin  Lutein, Mg, Collagen, 유산균, 알로에 베라
# text :  # CKD stage 3 d/t HTN    # HTN (3년)  # Dyslipidemia
# text :  # HTN (10yr)    # Sick sinus syndrome (2021.10.13 PM, VVI, Boston, 2022.6 EF 57%, LVEDD 6.1cm)  # AF,persistent (CHADS2VASC 3: HTN, age, female, CCr 44, BW 63kg)  # Dyslipidemia    [IMC med]  Diovan 160mg  Dichlozid  With  Atostarzet 10/10mg  Riroxaban
# text :  # HTN  # Dyslipidemia
# text :  # Lt knee DJD -> Lt TKRA (2007.01.03)  # HTN  # DM  # Dyslipidemia  # PSVT -> Ablation  # Angina
# text :  # ESRD on HD  - 2022.05 HD start  # HTN  # DM
# text :  # HTN (언제부터인지 잘 모르겠다.)  # BPH     [LMC med]  telmisartan/amlodipine  전립선 약
# text :  HTN/DM/Tbc +/+/-/

# %%
from googletrans import Translator
translator2 = Translator()
tt = '뇌사자 신장이식 대기자 상담 및 등록'
time.sleep(8)
ttt = translator2.translate(tt, dest='en')
time.sleep(8)
print(ttt.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-a83b68fa5a44> in <cell line: 4>()
#       2 translator2 = Translator()
#       3 tt = '뇌사자 신장이식 대기자 상담 및 등록'
# ----> 4 time.sleep(8)
#       5 ttt = translator2.translate(tt, dest='en')
#       6 time.sleep(8)
#
# NameError: name 'time' is not defined

# %%
# df['CC_translated']
# df['PI_translated']
# df['PH_translated']

# %%
df.to_excel('/content/translated_ds.xlsx')

# %%
# 학습용, 테스트용, 검증용 데이터 분할
X_train, X_temp, Y_train, Y_temp = train_test_split(df['transstr'], df['ICD10'], test_size=0.2, random_state=5)
X_test, X_val, Y_test, Y_val = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=7)

print(X_train)
print("=======================================\n")
print(X_test)
print("=======================================\n")
print(X_val)
print("=======================================\n")
print(Y_train)
print("=======================================\n")
print(Y_test)
print("=======================================\n")
print(Y_val)
# Out:
# 443    2021.09 CABG surgery 2023.06 CR 4.0, EGFR 14 2...
# 441    Since 2016, Hematuria had hematuria in 2022 TY...
# 66     23.04 LMC obstetrics and gynecology visits Hem...
# 773    60s HTN Diagnosis 2023.11.21 CR 1.58 BP 121/67...
# 131    I didn't have a previous checkup.2023. CR 1.83...
#                              ...
# 73     156/94/83, HOME BP <130/80, and Type A told fo...
# 400    # HTN, On Medication.Comprehensive Award at th...
# 118    The patient is a patient of 72 years old, curr...
# 701    HTN, DM 25 -year LMC Drug During LMC Pharmaceu...
# 206    The patient is a 69 -year -old (m) patient cur...
# Name: transstr, Length: 660, dtype: object
# =======================================
#
# 278    114-69-88 2 years ago Urology and Browno Holy ...
# 690    97-53-112 Diabetes and Hypertension-more than ...
# 108    145-75-85 2023.4.Microscopic Hematuria 2022.10...
# 499    2023/04 I heard that there is proteinuria duri...
# 755    The patient is a patient of 77 years old, curr...
#                              ...
# 228    The patient is a diagnostic name [Paralysis of...
# 151    # HTN (2022.)2023. CR 1.24 EGFR 41 EGFR K 5.7 ...
# 129    The patient is a diagnostic [DJD] patient of 8...
# 781    We will ask for consultation.The patient is a ...
# 159    20 years ago, DM, HTN diagnosis 10 years ago, ...
# Name: transstr, Length: 83, dtype: object
# =======================================
#
# 286    100/59/83 Known red blood cell symptoms (-), G...
# 654    The patient is the 87 -year -old patient curre...
# 488    The patient is a patient of 85 years old (F) c...
# 774    RT with RCC 20 years ago.Nephrectomy is a COPD...
# 602    In 2021, there has been proteinuria and commis...
#                              ...
# 360    The patient is a 72 -year -old (m) patient cur...
# 406    114/69/105, BW 79kg, HT 167cm, BMI 28 ESRD D/T...
# 483    161/78/59 Knwon HTN, DM, HCC RT.LOBECTOMY Stat...
# 436    Type 2 DM Diagnosis in the late 40s 2023.09.01...
# 273    Vitamins, omega, and other health foods (state...
# Name: transstr, Length: 83, dtype: object
# =======================================
#
# 443    N185
# 441    N183
# 66     R311
# 773    N183
# 131    N183
#        ...
# 73     Z524
# 400    R311
# 118    N183
# 701    N184
# 206    N183
# Name: ICD10, Length: 660, dtype: object
# =======================================
#
# 278    R311
# 690    N183
# 108    R311
# 499    R311
# 755    N183
#        ...
# 228    N183
# 151    N183
# 129    N183
# 781    R311
# 159    N183
# Name: ICD10, Length: 83, dtype: object
# =======================================
#
# 286    N028
# 654    N183
# 488    R601
# 774    N183
# 602    N059
#        ...
# 360    N183
# 406    N185
# 483    N184
# 436    N183
# 273    N178
# Name: ICD10, Length: 83, dtype: object

# %%
#https://zzaebok.github.io/deep_learning/nlp/Bert-for-classification/

# %%
device_name = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device_name)

# Tokenizer
tokenizer = AutoTokenizer.from_pretrained('NitzanBar/umls-spanbert')

# Model
model = AutoModelForSequenceClassification.from_pretrained('NitzanBar/umls-spanbert')
model.to(device)
# Out:
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 1024, padding_idx=0)
#       (position_embeddings): Embedding(512, 1024)
#       (token_type_embeddings): Embedding(2, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-23): 24 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=1024, out_features=1024, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=1024, out_features=2, bias=True)
# )

# %%
# tokenizer 토큰화 결과 확인
result = tokenizer.tokenize("130/61/69 Symptoms (-), edema (-), urbanic symptoms (-), doe (-) Known htn (> 10YRS), hypothyroidism, DL patient with LMC inspection CR 2.26, EGFR 29, HB 12.7Visit as.")
print(result)
print(tokenizer.vocab['symptoms'])
print([tokenizer.encode(token) for token in result])
# Out:
# ['130', '/', '61', '/', '69', 'symptoms', '(', '-', ')', ',', 'ed', '##ema', '(', '-', ')', ',', 'urban', '##ic', 'symptoms', '(', '-', ')', ',', 'do', '##e', '(', '-', ')', 'known', 'h', '##t', '##n', '(', '>', '10', '##yr', '##s', ')', ',', 'h', '##y', '##pot', '##hy', '##roid', '##ism', ',', 'd', '##l', 'patient', 'with', 'l', '##m', '##c', 'inspection', 'c', '##r', '2', '.', '26', ',', 'e', '##g', '##f', '##r', '29', ',', 'h', '##b', '12', '.', '7', '##vis', '##it', 'as', '.']
# 8006
# [[101, 7029, 102], [101, 120, 102], [101, 5391, 102], [101, 120, 102], [101, 5691, 102], [101, 8006, 102], [101, 113, 102], [101, 118, 102], [101, 114, 102], [101, 117, 102], [101, 5048, 102], [101, 108, 108, 9712, 1161, 102], [101, 113, 102], [101, 118, 102], [101, 114, 102], [101, 117, 102], [101, 3953, 102], [101, 108, 108, 178, 1665, 102], [101, 8006, 102], [101, 113, 102], [101, 118, 102], [101, 114, 102], [101, 117, 102], [101, 1202, 102], [101, 108, 108, 174, 102], [101, 113, 102], [101, 118, 102], [101, 114, 102], [101, 1227, 102], [101, 177, 102], [101, 108, 108, 189, 102], [101, 108, 108, 183, 102], [101, 113, 102], [101, 135, 102], [101, 1275, 102], [101, 108, 108, 194, 1197, 102], [101, 108, 108, 188, 102], [101, 114, 102], [101, 117, 102], [101, 177, 102], [101, 108, 108, 194, 102], [101, 108, 108, 9814, 102], [101, 108, 108, 177, 1183, 102], [101, 108, 108, 187, 7874, 102], [101, 108, 108, 1110, 1306, 102], [101, 117, 102], [101, 173, 102], [101, 108, 108, 181, 102], [101, 5351, 102], [101, 1114, 102], [101, 181, 102], [101, 108, 108, 182, 102], [101, 108, 108, 172, 102], [101, 11820, 102], [101, 172, 102], [101, 108, 108, 187, 102], [101, 123, 102], [101, 119, 102], [101, 1744, 102], [101, 117, 102], [101, 174, 102], [101, 108, 108, 176, 102], [101, 108, 108, 175, 102], [101, 108, 108, 187, 102], [101, 1853, 102], [101, 117, 102], [101, 177, 102], [101, 108, 108, 171, 102], [101, 1367, 102], [101, 119, 102], [101, 128, 102], [101, 108, 108, 191, 1548, 102], [101, 108, 108, 1122, 102], [101, 1112, 102], [101, 119, 102]]

# %%
class EMRDiagcdDataset(Dataset):

    def __init__(self, df):
        self.df = df

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        record = self.df.iloc[index]['transstr']
        # diagcd = self.df.iloc[index]['ICD10']
        diagcd = self.df.iloc[index]['encoded_ICD10']

        return record, diagcd

        # tokens = self.tokenizer(
        #     record,
        #     return_tensors='pt',
        #     truncation=True,
        #     padding='max_length')

        # input_ids = tokens[input_ids].squeeze(0)
        # attention_mask  = tokens[attention_mask ].squeeze(0)
        # token_type_ids  = torch.zeros_like(token_type_ids )

        # return {
        #     'input_ids' : input_ids,
        #     'attention_mask' : attention_mask,
        #     'token_type_ids' : token_type_ids,
        # }, torch.tensor(diagcd)

# %%
# label encoding
unique_label = Y_train.unique()
print("1 :", unique_label)

label_encoder = LabelEncoder()
label_encoder.fit(unique_label)

# print("2 : ", label_encoder)

temp_df = Y_train.to_frame()
temp_df['encoded_ICD10'] = label_encoder.transform(temp_df['ICD10'])
Y_train_encoding = pd.Series(temp_df['encoded_ICD10'])
# Y_train_encoding = Y_train_encoding.rename('encoded_ICD10')
# print("2 :", Y_train_encoding)
# Out:
# 1 : ['N185' 'N183' 'R311' 'R601' 'N184' 'N178' 'N391' 'N182' 'N028' 'Z524'
#  'R808' 'N029' 'N059' 'R798']

# %%
print(Y_train)
# Out:
# 443    N185
# 441    N183
# 66     R311
# 773    N183
# 131    N183
#        ...
# 73     Z524
# 400    R311
# 118    N183
# 701    N184
# 206    N183
# Name: ICD10, Length: 660, dtype: object

# %%
print(Y_train_encoding[:5])
# Out:
# [7 5 9 5 5]

# %%
train_df = pd.concat([X_train, Y_train_encoding, Y_train], axis=1)
train_dataset = EMRDiagcdDataset(train_df)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)

# %%
train_df.to_excel('/content/train_df.xlsx')

# %%
optimizer = Adam(model.parameters(), lr=1e-2)
criterion = torch.nn.Softmax()
itr = 1
p_itr = 50
epochs = 1
total_loss = 0
total_len = 0
total_correct = 0

# %%
# train
model.train()

for epoch in range(epochs):
    for record, diagcd in train_loader:
        optimizer.zero_grad()
        # print("record: ", record)
        # print("diagcd: ", diagcd)
        encoded_record = tokenizer(record, padding=True, truncation=True, max_length=512, return_tensors="pt")
        # encoded_record = encoded_record.to(device)
        # print(type(encoded_record))
        diagcd = torch.tensor(diagcd)
        # diagcd = torch.tensor(list(diagcd), dim=0).to(device)

        outputs = model(**encoded_record, labels=diagcd)

        loss = outputs.loss
        logits = outputs.logits

        predict = torch.argmax(F.softmax(logits), dim=14)
        correct = predict.eq(diagcd)

        total_correct += correct.sum().item()
        total_len += len(diagcd)
        total_loss += loss.item()

        loss.backward()
        optimizer.step()

        if itr % p_itr == 0:
            print('[Epoch {}/{}] Iteration {} -> Train Loss: {:.4f}, Accuracy: {:.3f}'.format(epoch+1, epochs, itr, total_loss/p_itr, total_correct/total_len))
            total_loss = 0
            total_len = 0
            total_correct = 0

        itr += 1
# Out:
# <ipython-input-118-0be101af0015>:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   diagcd = torch.tensor(diagcd)

# %%
test_df = pd.concat([X_test, Y_test], axis=1)
print(test_df)

test_dataset = EMRDiagcdDataset(test_df)
test_loader = DataLoader(test_dataset, batch_size=len(test_dataset), shuffle=True)
# Out:
#                                               transstr ICD10
# 278  114-69-88 2 years ago Urology and Browno Holy ...  R311
# 690  97-53-112 Diabetes and Hypertension-more than ...  N183
# 108  145-75-85 2023.4.Microscopic Hematuria 2022.10...  R311
# 499  2023/04 I heard that there is proteinuria duri...  R311
# 755  The patient is a patient of 77 years old, curr...  N183
# ..                                                 ...   ...
# 228  The patient is a diagnostic name [Paralysis of...  N183
# 151  # HTN (2022.)2023. CR 1.24 EGFR 41 EGFR K 5.7 ...  N183
# 129  The patient is a diagnostic [DJD] patient of 8...  N183
# 781  We will ask for consultation.The patient is a ...  R311
# 159  20 years ago, DM, HTN diagnosis 10 years ago, ...  N183
#
# [83 rows x 2 columns]

# %%
# evaluation
model.eval()

total_len = 0
total_correct = 0

for record, diagcd in test_loader:

    encoded_record = tokenizer(record, padding=True, truncation=True, max_length=512, return_tensors="pt")
    encoded_record, diagcd = encoded_record.to(device), diagcd.to(device)

    outputs = model(**encoded_record, labels=diagcd)

    logits = outputs.logits

    predict = torch.argmax(F.softmax(logits), dim=14)
    correct = predict.eq(diagcd)

    total_correct += correct.sum().item()
    total_len += len(diagcd)

print('Test accuracy: ', total_correct / total_len)
